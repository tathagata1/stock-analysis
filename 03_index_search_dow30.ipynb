# %% [markdown]
# # Index Search
#
#         Scan an index universe (S&P 500, Nasdaq-100, Dow 30) and rank tickers using the same prediction pipeline.

# %%
import analysis_blocks

# %% [markdown]
# ## Block 1: Parameters

# %%
index_name = "dow30"  # options: sp500, nasdaq100, dow30
limit = 10  # reduce for quicker scans
include_fundamentals = True
include_sentiment = True  # True requires API keys and adds latency

# %% [markdown]
# ## Block 2: Run Index Scan

# %%
result = analysis_blocks.run_index_search_workflow(
    index_name=index_name,
    limit=limit,
    include_sentiment=include_sentiment,
    include_fundamentals=include_fundamentals,
)
# Out:
# ERROR:root:Error reading index constituents for dow30: 403 Client Error: Too many requests. Please respect our robot policy https://w.wiki/4wJS. (dd12474) for url: https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average

# %% [markdown]
# ## Block 3: Ranked Output

# %%
ranked = result["prediction_summary"]
signal_only = ranked[ranked["Signal_Text"] != "HOLD"].reset_index(drop=True)

signal_only.to_csv("index_search_signals.csv", index=False)

signal_only.head(25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 ranked = result["prediction_summary"]
# ----> 2 signal_only = ranked[ranked["Signal_Text"] != "HOLD"].reset_index(drop=True)
#       4 signal_only.to_csv("index_search_signals.csv", index=False)
#       6 signal_only.head(25)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Signal_Text'

# %%
#signal_only.tail(25)

# %% [markdown]
# ## Block 4: Inspect One Candidate

# %%
#ticker = signal_only.iloc[0]["TICKER"] if not signal_only.empty else None
#ticker, result["analyses"][ticker]["df_tested"].head() if ticker else (None, None)

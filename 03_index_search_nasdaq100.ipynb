# %% [markdown]
# # Index Search
#
#         Scan an index universe (S&P 500, Nasdaq-100, Dow 30) and rank tickers using the same prediction pipeline.

# %%
import analysis_blocks

# %% [markdown]
# ## Block 1: Parameters

# %%
index_name = "nasdaq100"  # options: sp500, nasdaq100, dow30
limit = 100  # reduce for quicker scans
include_fundamentals = True
include_sentiment = False  # True requires API keys and adds latency
ticker_cache_dir = "cache"
ticker_cache_max_age_hours = 24

# %% [markdown]
# ## Block 2: Run Index Scan

# %%
result = analysis_blocks.run_index_search_workflow(
    index_name=index_name,
    limit=limit,
    include_sentiment=include_sentiment,
    include_fundamentals=include_fundamentals,
    use_ticker_cache=True,
    ticker_cache_dir=ticker_cache_dir,
    ticker_cache_max_age_hours=ticker_cache_max_age_hours,
)

# %% [markdown]
# ## Block 3: Ranked Output

# %%
ranked = result["prediction_summary"]
signal_only = ranked[ranked["Signal_Text"] != "HOLD"].reset_index(drop=True)

signal_only.to_csv("output/03_index_search_nasdaq100.csv", index=False)

signal_only.head(100)
# Out:
#   current_date TICKER  Signal Signal_Text    cumulative_return  \
# 0     20260314   CHTR       1    WEAK BUY  Positive: Excellent
# 1     20260314  CMCSA       1    WEAK BUY  Positive: Excellent
# 2     20260314    PDD       1    WEAK BUY  Positive: Excellent
# 3     20260314   BKNG       1    WEAK BUY       Negative: Poor
# 4     20260314   TMUS       1    WEAK BUY       Negative: Poor
#
#      sharpe_ratio           sortino_ratio    max_drawdown  \
# 0   Positive: Bad          Positive: Good  Negative: Poor
# 1   Positive: Bad          Positive: Good  Negative: Poor
# 2   Positive: Bad          Negative: Poor  Negative: Poor
# 3  Negative: Poor  Negative: Unacceptable  Negative: Poor
# 4  Negative: Poor  Negative: Unacceptable  Negative: Poor
#
#            calmar_ratio
# 0        Positive: Good
# 1        Positive: Good
# 2  Positive: Acceptable
# 3        Negative: Poor
# 4        Negative: Poor

# %% [markdown]
# # Current Holdings Review
#
#         Modular notebook for reviewing your current holdings, running the prediction pipeline, and simulating portfolio actions from the holding date.

# %%
import pandas as pd
import analysis_blocks

# %% [markdown]
# ## Block 1: Parameters

# %%
portfolio_path = "portfolio/real_portfolio.json"
initial_funds = 1000
include_sentiment = True  # True requires API keys and adds latency

# %% [markdown]
# ## Block 2: Run Holdings Workflow

# %%
result = analysis_blocks.run_holdings_workflow(
    portfolio_path=portfolio_path,
    initial_funds=initial_funds,
    include_sentiment=include_sentiment,
)
# Out:
# ERROR:root:Error in get_news_post for https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_cb11fd71-d529-4137-9b98-0e62db65e214: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_cb11fd71-d529-4137-9b98-0e62db65e214
# ERROR:root:Error in get_news_post for https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_eaef7ee7-2f53-4b7c-a73f-6f130c2b8ec0: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_eaef7ee7-2f53-4b7c-a73f-6f130c2b8ec0
# ERROR:root:Error in get_news_post for https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_709d23b3-4f1e-463e-8aa9-d6de4213ffa0: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_709d23b3-4f1e-463e-8aa9-d6de4213ffa0
# ERROR:root:Error in get_news_post for https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_88e0f08e-a3bf-4744-9a6c-e35bd5e65265: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_88e0f08e-a3bf-4744-9a6c-e35bd5e65265
# ERROR:root:Error in get_news_post for https://slickdeals.net/f/19222084-legion-pro-5-laptop-16-1600p-oled-165hz-ryzen-8745hx-rtx-5060-32gb-ram-1tb-ssd-1180-free-shipping: 403 Client Error: Forbidden for url: https://slickdeals.net/f/19222084-legion-pro-5-laptop-16-1600p-oled-165hz-ryzen-8745hx-rtx-5060-32gb-ram-1tb-ssd-1180-free-shipping

# %% [markdown]
# ## Block 3: Summaries

# %%
holdings_view = analysis_blocks.extract_holdings_pnl_view(result)
prediction_summary = result["prediction_summary"].sort_values(by=["Signal", "cumulative_return"], ascending=[False, False])
portfolio_sim_summary = result["portfolio_simulation_summary"].sort_values(by=["signal_number", "unrealized_gain_loss_%"], ascending=[False, False])
holdings_view

# %%
prediction_summary

# %%
portfolio_sim_summary
